# %%
import pyspark
from pyspark import SparkContext
sc = SparkContext.getOrCreate();
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-U6TP5SP:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import os
import tweepy as tw

# %%
#sc.stop()

# %%
# API Keys and Tokens
consumer_key = 'TXq9cSiPgoZvcKFb2h1wQcnfF'
consumer_secret = 'Hf3jBUCLDd065ndxrPqhElNCdq4PUYuC0zh0MAyLOAc5vICA7C'
access_token = '1423514561668272128-Exw0A7NmUy6txQg2JIOCzmATbvZeJY'
access_secret = 'GyJnh9o1iCDbtDHtJXXuGPqjtDZ4OxRgoy7W7gC4sPeLx'

# %%
auth = tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_secret)
api= tw.API(auth,wait_on_rate_limit =True)

# %%
search_words = "#olympic"
date_since = "2021-08-07"

# %%
tweets = tw.Cursor(api.search,q=search_words,lang="en",since=date_since).items(200)
#tweets = tw.Cursor(api.search, lang="en",since=date_since).items(20)
[tweet.text for tweet in tweets]
# Out:
# ['Congratulations to all our winners and participants at the Olympics.\nPRIDE OF INDIA...\n#tokyo #olympics #karate… https://t.co/QZh93Qgyuf',
#  "RT @satwantrissam: @UniversityJammu to name it's gymnasium hall after 2 time #Olympic Medalist &amp; ace Indian shuttler @Pvsindhu1 . \n#JammuKa…",
#  "RT @satwantrissam: @UniversityJammu to name it's gymnasium hall after 2 time #Olympic Medalist &amp; ace Indian shuttler @Pvsindhu1 . \n#JammuKa…",
#  "RT @satwantrissam: @UniversityJammu to name it's gymnasium hall after 2 time #Olympic Medalist &amp; ace Indian shuttler @Pvsindhu1 . \n#JammuKa…",
#  "RT @satwantrissam: @UniversityJammu to name it's gymnasium hall after 2 time #Olympic Medalist &amp; ace Indian shuttler @Pvsindhu1 . \n#JammuKa…",
#  "Just published on @Playing_Pasts website\n\nThe final installment of @andykerrcarter's informative series - \n\nThe… https://t.co/S6BjE9yy4h",
#  "RT @MissiNewsRoom: 'These things take a community': Katie Vincent was proud to share her #Olympic bronze medal with friends and family at h…",
#  "'These things take a community': Katie Vincent was proud to share her #Olympic bronze medal with friends and family… https://t.co/L8Wmfc4ob0",
#  "Bronze medalist ''A'' TEDDY RINER of France poses for the cameras after the men's judo +100 kg final during the Tok… https://t.co/w1ajT5tree",
#  'RT @bwfmedia: A number of #Olympic #badminton medallists feature in our next instalment of My Perfect Badminton Player with @C_Langridge…',
#  'RT @editorji: A day after cheering for the Indian #Olympic contingent from ramparts of Red Fort, Prime Minister #NarendraModi met them for…',
#  'A number of #Olympic #badminton medallists feature in our next instalment of My Perfect Badminton Player with… https://t.co/IJeaec5xVP',
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  'RT @editorji: A day after cheering for the Indian #Olympic contingent from ramparts of Red Fort, Prime Minister #NarendraModi met them for…',
#  'Residents of Magnolia House #carehome in #Cottingham celebrated #Tokyo2020 in style with their own version of the… https://t.co/ECF9TwRBHm',
#  'RT @neerubhatia3: A story about the much awaited #Olympic medal in #Hockey  In the latest issue of @TheWeekLive \n\nFitness, mental toughness…',
#  'RT @ArianSadiqi: I am very honoured and privileged to have been asked to take the role of the Chef de Mission for Tokyo 2020 Paralympic Gam…',
#  "RT @ysjagan: Congratulations to @Neeraj_Chopra1, a serving soldier of Indian Army, who has made India proud by winning the nation's first-e…",
#  "RT @achyuta_samanta: Hon'ble CM of Odisha, @Naveen_Odisha spoke to hockey players after their win over Germany. It is a moment of pride for…",
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  "RT @satwantrissam: @UniversityJammu to name it's gymnasium hall after 2 time #Olympic Medalist &amp; ace Indian shuttler @Pvsindhu1 . \n#JammuKa…",
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  'Celebrating the success of #Olympic  medalist Saikhom #MirabaiChanu  , the weightlifter here on Friday visited the… https://t.co/DygF0miFnh',
#  "@narendramodi has time to meet #olympic medal winners even have breakfast with them but he doesn't have time to mee… https://t.co/xNzjNmCY9g",
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  'RT @DelhiBpclRetail: #Olympic boxing champ @boxervijender kickstarted @Amul_Coop Parlor, at our RO M/s Jaglan Filling Station in Dwarka wit…',
#  "RT @satwantrissam: @UniversityJammu to name it's gymnasium hall after 2 time #Olympic Medalist &amp; ace Indian shuttler @Pvsindhu1
#  'RT @bwfmedia: THROWBACK | Watch #Olympic bronze medallists Aaron Chia/Soh Wooi Yik 🇲🇾 in action earlier this year 🆚 Choi SolGyu/Seo Seungja…',
#  'RT @PatrickKinas: In 1st game back since July 15th w/@DurhamBulls, @TeamUSA #Olympic silver medalist #ShaneBaz worked a scheduled 3IP, reti…',
#  '#PrimeMinister Invites #Olympic\nAthletes For The Morning Tea At His Residence On Monday  \n\nhttps://t.co/LTanXef2ES #latest_news',
#  "RT @Jerusalem_Post: From the recent controversies with #Poland to Israel's recent performance at the #Olympic Games, readers of the Jerusal…",
#  'In 1st game back since July 15th w/@DurhamBulls, @TeamUSA #Olympic silver medalist #ShaneBaz worked a scheduled 3IP… https://t.co/CDUYdohXR2',
#  "RT @HarsimratBadal_: Congratulations @Neeraj_chopra1 for winning an #Olympic gold, in men's javeline throw, a first for any Indian at the g…",
#  'Learn #Flags, it helps watching the #Olympic games or any sports in the #world https://t.co/o5xA73FQiC',
#  "Olympic hero Jack Woolley issues update from hospital bed following 'random attack' that left him bleeding #attack… https://t.co/QAOxcZTErG",
#  "Olympic hero Jack Woolley issues update from hospital bed following 'random attack' that left him bleeding #attack… https://t.co/oLLHQGAic6",
#  "Olympic hero Jack Woolley issues update from hospital bed following 'random attack' that left him bleeding #attack… https://t.co/qlhakMsVPM",
#  "Olympic hero Jack Woolley issues update from hospital bed following 'random attack' that left him bleeding #attack… https://t.co/ZAaeQ3Ol0w",
#  '@ellisbross with #SunPeaks Mayor Al Raine and #Olympic champion, and former Canadian Senator, #NancyGreene Raine https://t.co/QapEUeK2zS',
#  'RT @ramcosmartbuild: A big round of applause for all the winners! You guys have won the "Tokyo Olympic Contest - 2020". We appreciate the r…',
#  'RT @Neiphiu_Rio: Congratulations, P. V. Sindhu @Pvsindhu1 on winning the second medal for India and becoming the first Indian woman athlete…',
#  "From the recent controversies with #Poland to Israel's recent performance at the #Olympic Games, readers of the Jer… https://t.co/G7reaNeCsn",
#  'RT @hgsdhaliwalips: What effort &amp; practice takes you to #Olympic success! the incredible and almost unbelievable flexibility of #Neeraj Cho…',
#  'A fleeting observation. "Marco Polo" &amp; "cannonballs" are surprisingly apropos names for mostly male-initiated (all… https://t.co/z4SPW3ENdc']

# %%
new_search= search_words 
new_search
# Out:
# '#olympic'

# %%
tweets = tw.Cursor(api.search, q=new_search,lang="en",since=date_since).items(500)
users_details = [[tweet.user.screen_name,tweet.user.name,tweet.user.followers_count,tweet.user.verified]for tweet in tweets]
users_details
# Out:
# [['RakeshK55737177', 'Rakesh Khatana', 21, False],
#  ['BotJammu', 'Jammu Bot 🤖', 491, False],
#  ['BotJammu', 'Jammu Bot 🤖', 491, False],
#  ['BotJammu', 'Jammu Bot 🤖', 491, False],
#  ['BotJammu', 'Jammu Bot 🤖', 491, False],
#  ['Playing_Pasts',
#   'ℙ𝕝𝕒𝕪𝕚𝕟𝕘 ℙ𝕒𝕤𝕥𝕤🤼\u200d♀️⛹️\u200d♀️🤺🏊\u200d♂️🏏⛸🤸\u200d♂️',
#   1475,
#   False],
#  ['RudyCuzzetto', 'Rudy Cuzzetto, MPP', 9186, True],
#  ['MissiNewsRoom', 'The Mississauga News', 30827, False],
#  ['RodrigoMarinJPN', 'Rodrigo Reyes Marín', 2957, False],
#  ['JChaiyasothi', 'Jarkkrrapobb Chaiyasothi', 103, False],
#  ['ajay79927249', 'ajay', 60, False],
#  ['bwfmedia', 'BWF', 197396, True],
#  ['saiveer_reddy', 'Saiveer Reddy K', 183, False],
#  ['Pramod08081976', 'Pramod Vishwakarma', 150, False],
#  ['Recognition1st', 'Recognition PR', 2261, False],
#  ['deeptiraonayak', 'Deepti', 203, False],
#  ['b_snow_tf_2', 'ゆゆ_2nd', 229, False],
#  ['YsrcpSupporters', 'YSRCP Supporters', 489, False],
#  ['diptisumanti', 'dipti prakash mohanty', 12, False],
#  ['RenuVermaBPC', 'Renu Verma', 314, False],
#  ['Gupta_Bihar', 'Abhishek Gupta', 240, False],
#  ['BatraJeetu', 'JatinderBatra', 29, False],
#  ['PeterGantzerBPC', 'Peter Gantzer', 1862, False],
#  ['the_newsmen', 'The Newsmen', 1845, False],
#  ['arsiwalamurtuza', 'Murtuza S Arsiwala✋', 8363, False],
#  ['CharuJa00904835', 'Charu Jain', 2, False],
#  ['BPCLimited', 'Bharat Petroleum', 315347, True],
#  ['BPCLRetail', 'BPCL Fuel Stations', 13753, False],
#  ['SODELHI_SOUTH', 'Niranjan', 60, False],
#  ['Dipikka_M', 'Dipikka', 1372, False],
#  ['CallMeAhmjusAyn', "Ahmjus Ay'n: So - I'm a Nancy!", 2378, False],
#  ['AdityaM8122', 'Aditya Mathur', 122, False],
#  ['Kshitij1404', 'KshitijM', 59, False],
#  ['MKaur_Preet', 'M Kaur (Preet) 🇮🇳', 2493, False],
#  ['SunnySandhulive', 'Bikram Sandhu', 89, False],
#  ['botcybersec', 'CyberSec BOT', 1947, False],
#  ['cyber_int', 'Cyberint', 1063, False],
#  ['souravm1976', 'Sourav Mukherjee', 942, False],
#  ['myfieldindia', 'My Field', 18, False],
#  ['BajajCharita', 'Charita bajaj', 96, False],
#  ['NKS0010', 'Navneet Kumar Singh 🇮🇳', 1536, False],
#  ['Jai_yasu_tulip', 'JK Saxena', 30, False],
#  ['RamonWrites', 'Ramon Youseph', 897, False],
#  ['chenkc11', 'chen k.c.', 404, False],
#  ['DelhiBpclRetail', 'BPCLDelhiRetail Territory', 188, False],
#  ['satwantrissam', 'Dr.Satwant Singh Rissam, Ph.D', 710, False],
#  ['jkuhn4hotmail', 'jim kuh', 1656, False],
#  ['TobySportsLaw', 'Toby Hill', 84, False],
#  ['BORSAM_IP', 'Borsam IP', 127, False],
#  ['Diajav2', 'labek ya rasool Allah', 492, False],
#  ['UiTV_Connect', 'UiTV Connect', 1156, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['editorji', 'editorji', 40753, True],
#  ['Deepernews1', 'Deepernews', 489, False],
#  ['Outlookindia', 'Outlook Magazine', 233711, True],
#  ['KamalSi94997791', 'Kamal Singh', 11, False],
#  ['VishnuReddy_kvr', 'Vishnu_Reddy', 70, False],
#  ['neerubhatia3', 'neeru bhatia', 7317, False],
#  ['saymyeun', 'saymyeun', 15, False],
#  ['latestly', 'LatestLY', 70626, True],
#  ['LeicsCares', 'Leicestershire Cares #TogetherWeCan', 5083, False],
#  ['VianaTeresita', 'Teresita c.Viana', 184, False],
#  ['TheQuint', 'The Quint', 683754, True],
#  ['MahaBJPMinority', 'MahaBJPMinority', 599, False],
#  ['zahidpatka', 'Zahid Patka', 3487, False],
#  ['HLSportandRec', 'Lords Sport and Recreation Committee', 550, False],
#  ['K_arnav_anand', 'Arnav Anand', 65, False],
#  ['KayeMenner', 'Kaye Menner', 24185, False],
#  ['RamRaghavBhakt1', 'RamRaghavBhakt', 61, False],
#  ['RoystanLewis', 'Roystan Lewis🇮🇳', 338, False],
#  ['alexandre_sgroi', 'alexandre sgroi', 1233, False],
#  ['chelluboinavenu', 'VenuGopalaKrishna Chelluboina', 514, False],
#  ['alokkumars161', 'Alok Kumar', 42, False],
#  ['miss_shah__', 'Shayzay', 11418, False],
#  ['unmtextiles', 'U.N.Murugesan & Co', 1, False],
#  ['IamTannistha', 'Tannistha Bhadra', 10, False],
#  ['aerezona', 'کپتان کا سپاہی', 252, False],
#  ['J7Consulting', 'J7 Consulting Pvt. Ltd.', 43, False],
#  ['nnn_nikky', 'NNN', 5, False],
#  ['moorthi123456', 'moorthi', 0, False],
#  ['Balraj12637744', 'Balraj', 10, False],
#  ['ChitranshLata', 'Chitransh Lata', 1, False],
#  ['minotauresse', 'Dana McDevitt', 4338, False],
#  ['SOEBristol', 'School of Education (Bristol University)', 3172, False],
#  ['rsdaroga', 'RadheyShyam', 93, False],
#  ['nyeongcnvs', 'sky ☁️ 08.26', 164, False],
#  ['Anamika24557044', 'Anamika Verma', 4, False],
#  ['CMokalkar', 'Chandan Mokalkar', 108, False],
#  ['PeteMoring', 'Pete Moring', 4209, False],
#  ['CNBCTV18News', 'CNBC-TV18', 957045, True],
#  ['defcvrsh', 'SOMO : FUME•GRAYGROUND', 509, False],
#  ['arsthusy', '𝗧𝗵𝘂𝘀𝘆 FUME', 761, False],
#  ['Anshujourno92', 'Anshu Singh', 332, False],
#  ['sevenbabieess', 'joy☾°🔗', 603, False],
#  ['sevendless', '🌏⚖️', 22229, False],
#  ['rzyhrry1', 'Çrãzy Çhêrry', 14, False],
#  ['TrendGrnd', 'TrendGrnd', 11, False],
#  ['insidethegames', 'insidethegames', 34117, False],
#  ['KhandishJ', 'KhandIsh Jamsrandorj', 1220, False],
#  ['globalhealthbot', 'Globalhealth Bot', 1011, False],
#  ['Neoprimesports', 'Neo Prime Sports', 86, False],
#  ['b_komathi', 'KOMATHI B KOMATHI B', 10, False],
#  ['Kofi_Smiles', 'TheSmileMaker 🌱', 4349, False],
#  ['malarianomoreIN', 'Malaria No More India', 121, False],
#  ['Deepa88117182', 'Deepa', 1, False],
#  ['ManishM78063675', 'Manish Manish', 0, False],
#  ['GraziaIndia', 'Grazia India', 1587085, True],
#  ['bose_shohini', 'Shohini Bose', 192, False],
#  ['Golden_Seagul', 'Souvik Chakraborty', 1461, False],
#  ['Raghav_Bahl', 'Raghav Bahl', 112795, True],
#  ['cdroundtable', 'China Daily Events', 949, False],
#  ['psandeen', 'Paul Sandeen', 9, False],
#  ['saadhyudu2011', 'PardhasaradhiGrandhi', 2509, False],
#  ['aishvaryjain', 'AISHVARYA JAIN', 475, False],
#  ['thrizzxiaangeli', 'Xean ThrizzxiaAngeli', 144, False],
#  ['TODDCastPodcast', 'Todd Hancock', 8420, False],
#  ['RodrigoMarinJPN', 'Rodrigo Reyes Marín', 2957, False],
#  ['aroraakshay2312', 'Akshay Arora', 124, False],
#  ['Mandeep32088298', 'Mandeep Singh', 5, False],
#  ['ndtvvideos', 'NDTV Videos', 314308, True],
#  ['Alex17243', 'Alex1724', 310, False],
#  ['AllIndiaTransp5', 'All India Transport Packers & Movers', 21, False],
#  ['AwaraDil21', 'Ash ', 327, False],
#  ['ndtv', 'NDTV', 16004088, True],
#  ['Alejand53190487', 'Alejandro', 130, False],
#  ['inapoem', 'J L Jones', 3390, False],
#  ['VKAddictMuch', 'AnaMarieTV', 3473, False],
#  ['Lilianafelizsie', 'Lili Pro', 115, False],
#  ['sondosalas', 'SonDosAlas', 78, False],
#  ['hookem47', 'meredith weaver', 94, False],
#  ['KissMeAgain99', 'Taylor💙', 45410, False],
#  ['ecvhvhvhvhv', 'Æcah 🏴🏴🏴', 91, False],
#  ['RupaliR97025766', 'RJ Raunak', 0, False],
#  ['Impexperts', 'Impexperts: World of Import-Export (GFE Group)', 970, False],
#  ['rhoadsoda', 'Zach Rhoads', 1214, False],
#  ['TejaMbg', 'MBG TEJA YT', 0, False],
#  ['prmd_jnj', 'Parmod Juneja', 7, False],
#  ['dushsahu', 'Dushyant', 42, False],
#  ['Haileab_Tesfay', 'Haileab', 672, False],
#  ['RodrigoMarinJPN', 'Rodrigo Reyes Marín', 2957, False],
#  ['SCIPUniMelb', 'SCIP UniMelb', 911, False],
#  ['WicketWolf', 'wicket wolf', 411, False],
#  ['ChicagoCouncil', 'The Chicago Council', 21519, True],
#  ['Khanji61685240', 'Khanji', 1409, False],
#  ['MusingsBach', 'Bach musings', 55, False],
#  ['bissettfinfit', 'Tracey Bissett (she/her/hers)', 1300, False],
#  ['leila_pontes', 'Leila Pontes', 1412, False],
#  ['VERITASearch', 'Why', 438, False],
#  ['ilwyshs_', 'n', 2, False],
#  ['Giu_Fabiana', 'FABIANA', 4175, False],
#  ['BornSickkkk_', '✨ Queens need Kings', 2015, False],
#  ['JoseFer11011724', 'Jose Ferreira', 180, False],
#  ['LightspeedSteps', 'Lightspeed', 979, False],
#  ['AdmirableWomen', 'Admirable Women', 3055, False],
#  ['chrispilz', 'Chris PIlz', 1565, False],
#  ['ParksExperience', 'The National Parks Experience', 2238, False],
#  ['WB6DYN', 'Dan Thom,B.S.,J.D.🖤💙🖤', 6159, False],
#  ['LamireauT', 'LAMIREAU Thierry', 1239, False],
#  ['jamiehansman', 'Jamie Hansman', 228, False],
#  ['TOKiON_jp', 'TOKION', 225, False],
#  ['BevVincent', 'Bev Vincent', 8233, True],
#  ['ClassicalxMusic', 'Classical Music', 3265, False],
#  ['AdeloyeAyotunde', 'Hannibal thee African Giant 🇳🇬🇫🇷🇪🇺', 549, False],
#  ['TeshawnEdmonds', 'Teshawn LeVarr Edmonds', 3938, False],
#  ['LeydiRivas10', 'Leydi Rivas', 363, False],
#  ['bevsackville', 'Beverley Sackville', 559, False],
#  ['EnbyBeanBillie', 'Billie x 🤘', 1732, False],
#  ['vkookisawesome2', 'ldrago', 3, False],
#  ['PagelJphans72', 'Justin Pagel', 2425, False],
#  ['patriGiancotti', 'Patrizia Giancotti', 7590, False],
#  ['Prettyboycarles', 'Charles', 51, False],
#  ['Pat73115893', 'Pat', 193, False],
#  ['livingstonfinan', 'Peter Livingston', 1474, False],
#  ['KavumaSsemujju', 'Kavuma David Ssemujju', 157, False],
#  ['chron', 'Chron', 816, False],
#  ['natationist', 'Dave Day', 858, False],
#  ['ManojTomar_IYC', 'Manoj Tomar', 2718, False],
#  ['swamy70316877', 'swamy', 0, False],
#  ['Dragofix', 'Dragofix', 4411, False],
#  ['RusEmbIndia', 'Russia in India 🇷🇺', 35158, True],
#  ['DiaryOtdGirl', 'Diary Of An OTD Girl', 874, False],
#  ['joeyjohnston813', 'Joey Johnston', 739, False],
#  ['ChiragB59325569', 'Chirag Bakshi', 21, False],
#  ['affiaz_', '🎻', 521, False],
#  ['TBTimes_Rays', 'Marc Topkin', 50997, True],
#  ['TheNationalBul1', 'The National Bulletin', 1061, False],
#  ['A5359201', 'Andrea 5359201', 36, False],
#  ['PatrickKinas', 'Patrick Kinas', 8472, False],
#  ['jhilyz91', 'JCB', 767, False],
#  ['joonoopenstory', 'Joono OpenStory', 3785, False],
#  ['aerezona', 'کپتان کا سپاہی', 252, False],
#  ['aerezona', 'کپتان کا سپاہی', 252, False],
#  ['aerezona', 'کپتان کا سپاہی', 252, False],
#  ['aerezona', 'کپتان کا سپاہی', 252, False],
#  ['AlanForseth', 'Alan Forseth', 829, False],
#  ['subhajitpaul26', 'Subhajit Paul', 27, False],
#  ['Aman11819124', 'Aman', 5, False],
#  ['Jerusalem_Post', 'The Jerusalem Post', 533689, True],
#  ['Shreya01838847', 'shreya', 6, False],
#  ['twoasianparents', 'The Parenting Asian America Project', 450, False],
#  ['melaniedbikes', 'Melanie D', 1551, False],
#  ['ymediagroup', 'ymediagroup', 481, False],
#  ['batmaneatsbabie', 'x - Nashville Assassins', 399, False],
#  ['adityapratapsri', 'Aditya Shrivastava', 1052, False],
#  ['SolodovDmitry', '𝑫𝒎𝒊𝒕𝒓𝒚 𝑺𝒐𝒍𝒐𝒅𝒐𝒗 🇷🇺', 645, False],
#  ['SubeSingh09', 'Sube Singh', 76, False],
#  ['Im_LN___', 'Lakshmi Narasimha Goud', 24, False],
#  ['DrBrighton4', 'Dr Brighton🇨🇺🇹🇿🇧🇸🇺🇸🇨🇵🇰🇪🇳🇱🇬🇧', 345, False],
#  ['muslimgirl', 'Muslim Girl', 41582, True],
#  ['BrandStoryboard', 'Storyboard', 14568, True],
#  ['ShibaniGharat', 'Shibani Gharat', 10550, True],
#  ['tobiaskintzel', 'Tobias Kintzel', 5184, False],
#  ['Denon_wing', 'PSCH', 6, False],
#  ['enilev', 'Eveline Ruehlin', 1581, False],
#  ['irfanzayn_', 'Irfan Zayn', 20, False],
#  ['heion_ni', 'ｍTIKO', 57, False],
#  ['miss__shah__', 'Shayzay', 45426, False],
#  ['ArunYad00000622', 'Arun Yadav', 1, False],
#  ['GSBorikar', 'G S Borikar', 155, False],
#  ['UW_Inter', 'United World', 917, False],
#  ['tobebetterrr_00', '∆: smileee', 2, False],
#  ['j_bon29', 'Jenn D. Young', 317, False],
#  ['Ananadu6', 'Ananadu', 68, False],
#  ['IthacaRetweet', '#twithaca Retweet', 300, False],
#  ['nikhilpoonia17', 'Nikhil Poonia', 4, False],
#  ['14850today', '14850 Today', 6022, False],
#  ['alex09dennis', 'Alex Dennis Münster', 36, False],
#  ['kishorech5', 'KKCH', 133, False],
#  ['Hiraeth1962', 'Gareth Rowlands', 106, False],
#  ['iamsam7860', 'Sam 🇵🇰', 16, False],
#  ['Burrowsdrums', 'Jeff Burrows 🇨🇦', 4510, False],
#  ['LiamCahill2013', 'Liam Cahill', 11270, False],
#  ['Ankita71330649', 'av', 22, False],
#  ['CNBCTV18News', 'CNBC-TV18', 957045, True],
#  ['LiuZhaoyang5', '琵琶湖', 855, False],
#  ['masalafilmy', 'filmymasala', 142, False],
#  ['andykerrcarter', 'Andy Carter', 1347, False],
#  ['bonobtha', 'BONO', 508, False],
#  ['aerezona', 'کپتان کا سپاہی', 252, False],
#  ['TxUsjkJArpAflNc', '点の記', 296, False],
#  ['prakash_aravind',
#   'Prakash N- Sports Lover & follower from Namakkal',
#   212,
#   False],
#  ['asnningsih__', 'Iyou', 57, False],
#  ['bose_shohini', 'Shohini Bose', 192, False],
#  ['the6thdecade', 'LouiseP', 1193, False],
#  ['TheQuint', 'The Quint', 683754, True],
#  ['NineteenNinetz', '🎪', 297, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['KOJOINVOICE1', 'K O J O. I N V O I C E', 468, False],
#  ['WestphalErin', 'Erin Westphal', 501, False],
#  ['RekhaSo26869084', 'Rekha Soni', 0, False],
#  ['SumitRa54053782', 'Sumit Ray', 0, False],
#  ['rjanna_rose', 'proud Engineer RJᴬᵃʳⁱ ᴵⁿ ᴮᴬᴳᴬⱽᴬᴺ', 735, False],
#  ['owifowav', 'suzuki adamu', 1042, False],
#  ['calUSAwrestling', 'CAUSAWrestling', 4192, False],
#  ['bissettfinfit', 'Tracey Bissett (she/her/hers)', 1300, False],
#  ['yeshaa_always', 'Yeshaa Patel ~Fangirl~✨', 288, False],
#  ['KajalYa59912835', 'Kajal Yadav', 0, False],
#  ['vishwa_samvad', 'Vishwa Samvada Kendra', 9390, False],
#  ['live_seasons', 'PaTh', 12007, False],
#  ['udayveeryadav5', 'NCIB LAKHIMPUR KHERI', 95, False],
#  ['ToreSvenning', 'Tore Svenning', 207, False],
#  ['ETNOWlive', 'ET NOW', 680918, True],
#  ['today_seniors', 'Seniors Today', 2113, False],
#  ['here_jagruk', 'Jagruk Hindustan', 801, False],
#  ['Prince_singh158', 'Prince_singh', 28, False],
#  ['davidsheldon95', 'David', 1818, False],
#  ['News9Tweets', 'News9', 28128, True],
#  ['ItikyalPs', 'SHO ITIKYAL PS', 15, False],
#  ['Rishiscribe', 'Rishikesh Bahadur D', 2040, False],
#  ['Parthib70309892', 'Parthiban', 1, False],
#  ['Priyanka7645', '𝑷𝒓𝒊𝒚𝒂𝒏𝒌𝒂🇮🇳🚩', 339, False],
#  ['thehatandbeard', 'paul', 573, False],
#  ['donnyfarmshop',
#   '#Global Doncaster 🇬🇧 ✈️🚄 Lynn & The Farm Shop',
#   4116,
#   False],
#  ['bihariMARINERS', "MAD;';'●♤MARINER💚❤", 140, False],
#  ['Mnh00051937', 'จอยขายข้าวมันไก่', 23, False],
#  ['KevinLe18338408', 'Kamlesh Sharma.', 18, False],
#  ['_PrashamShah_', 'Prasham Shah', 13, False],
#  ['vnzyrtx', 'nca', 37, False],
#  ['RockySoibam', 'Soibam Rocky Singh', 1749, False],
#  ['tejjaggavarapu', 'Tejkumarreddy', 73, False],
#  ['durgeshpatel89', 'दुर्गेश पटेल', 10156, False],
#  ['nistula', 'Nistula Hebbar', 192540, True],
#  ['PJay2417', 'patel jay2417', 240, False],
#  ['the_hindu', 'The Hindu', 7133604, True],
#  ['Unbelted', 'Aashish Bansal', 922, False],
#  ['Tanveer75506628', 'Tanveer Shaikh', 1923, False],
#  ['rnadeau12', 'Robin', 670, False],
#  ['zhyty12', 'zakk16_', 38, False],
#  ['Nonco11087178', 'Nonco', 1323, False],
#  ['tnfmagazine', 'The New Feminist', 252, False],
#  ['Playing_Pasts',
#   'ℙ𝕝𝕒𝕪𝕚𝕟𝕘 ℙ𝕒𝕤𝕥𝕤🤼\u200d♀️⛹️\u200d♀️🤺🏊\u200d♂️🏏⛸🤸\u200d♂️',
#   1475,
#   False],
#  ['dasarathi37', 'Dasarathinayak', 118, False],
#  ['LilyCarel', 'lily', 345, False],
#  ['RositaDivna', 'Rosita 💙', 6690, False],
#  ['ManpreetGoldy33', 'Manpreet Singh Goldy', 379, False],
#  ['SaraRob84303004', 'Sara Robles', 84, False],
#  ['CNBCTV18News', 'CNBC-TV18', 957045, True],
#  ['SameerS74752437', 'Sameer Saifi', 1, False],
#  ['HelpNowIndia', 'HelpNow', 1028, True],
#  ['AO_Sports', 'AhramOnlineSports', 17411, False],
#  ['VadivelMahesh1', 'VadivelMahesh', 8, False],
#  ['CNBCTV18News', 'CNBC-TV18', 957045, True],
#  ['ISanthosh99', 'Santhosh', 41, False],
#  ['refa_buana', 'Refa Buana', 391, False],
#  ['Raja08627068', 'Raja', 0, False],
#  ['MadCrazyHatter_', 'Abhimanyu Mathur', 698, False],
#  ['Mammukkafanboy1', 'since696', 229, False],
#  ['wilkesy49', 'Graeme Wilkes', 1466, False],
#  ['RobustStory', 'Robust Story', 146, False],
#  ['SachinR53880172', 'Sachin Ram', 27, False],
#  ['link2arj', 'Arjun K', 13, False],
#  ['SILENCEISGOLDE', '🥰🥰🥰🥰🥰🥰BringHomeWithBeacon', 571, False],
#  ['ShagunS26055441', 'Shagun Sharma', 1, False],
#  ['NuclearFront', 'Nuclear power plant is front for atomic bomb.', 246, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['afifadefi', 'A F I F A', 1923, False],
#  ['goldmedalfamous', 'Gold Medal Famous', 1031, False],
#  ['Rshivi04', 'Shivanshi Singh Raghuvanshi', 26, False],
#  ['phumz_24', 'Phumelela Mbande • OLY', 1375, False],
#  ['GOProject_SA', 'Girls Only Project', 225, False],
#  ['Fecadu2', 'Fecadu', 211, False],
#  ['naoakisetuko', 'ますく&るる', 2903, False],
#  ['Fecadu2', 'Fecadu', 211, False],
#  ['abhishekov1', 'abhishek', 60, False],
#  ['i_ammvp', 'Mayur Pawar', 86, False],
#  ['annie_tee1', 'A Timoney', 30, False],
#  ['ShivA78904869', 'ShivA', 3, False],
#  ['Asifsnadaf2', 'ಆಸಿಫ್ ಎಸ್ ನದಾಫ್', 19, False],
#  ['Armani_or_Die', '👑Sporax•👑🇬🇭', 1127, False],
#  ['SocialNewsXYZ', 'SocialNews.XYZ', 476, False],
#  ['agk4444', '#Rajanna(G🌐pi AdusuⓂilli)', 351, False],
#  ['surajgowdafans1', 'surajgowdafansclub', 6, False],
#  ['maharashtra', 'Maharashtra🇮🇳', 3264, False],
#  ['MrBirdPhoto', 'Michael Bird', 205, False],
#  ['Priya65765668', 'Priya', 0, False],
#  ['mumbai_mitra', 'Daily MumbaiMitra', 78, False],
#  ['Dailyvruttmitra', 'Daily Vruttmitra', 296, False],
#  ['yagbebi', 'Yemmi Agbebi, MBA #BlackLivesMatter', 4853, False],
#  ['Babyolly4', 'si comel☺❤', 1701, False],
#  ['syfrsyz', 'donut🇵🇸', 2384, False],
#  ['ElBronconator', 'J', 344, False],
#  ['ESPRIMO7', 'ESPRIMO＠ 江戸時代に戻ろう！\u3000Back to The Edo', 4757, False],
#  ['Amit_Raj_75', 'Amit Raj', 3, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['BeyanNegisty', 'Negisty Beyan', 95, False],
#  ['BeyanNegisty', 'Negisty Beyan', 95, False],
#  ['BeyanNegisty', 'Negisty Beyan', 95, False],
#  ['BeyanNegisty', 'Negisty Beyan', 95, False],
#  ['reubenbraham', 'Reuben Braham', 116, False],
#  ['BeyanNegisty', 'Negisty Beyan', 95, False],
#  ['livjr75', 'Moot&Academic', 58, False],
#  ['HistriaBooks', 'Histria Books', 1086, False],
#  ['RaajakumaraAppu', 'ಸಚಿನ್ (ಅಪ್ಪು❤)', 314, False],
#  ['BangaloreTimes1', 'Bangalore Times', 159815, True],
#  ['AshrafulGolam', 'A.I.M.Golam Rabbany', 38, False],
#  ['m_1926ai', 'まいまい🌟 ランニング女子', 496, False],
#  ['Heavensangel67', 'Tania🕊', 13654, False],
#  ['Heavensangel67', 'Tania🕊', 13654, False],
#  ['Wind_at_Dusk', '夕暮れの風🎗️台湾队🏅️', 281, False],
#  ['vishalwatts92', 'VISHAL WATTS', 103, False],
#  ['IshikaY57405179', 'Ishika Yadav', 3, False],
#  ['JaykumarBhamare', 'jaykumar bhamare', 6, False],
#  ['mumaralid', 'Mian Umar Ali', 755, False],
#  ['SportslightMed_', 'Sportslight Media', 72, False],
#  ['asghkel', 'Asghkel', 41, False],
#  ['JChaiyasothi', 'Jarkkrrapobb Chaiyasothi', 103, False],
#  ['BourneNatural', 'BourneNaturalBeauty', 5322, False],
#  ['lodha_siddhi', 'Siddhi Lodha', 13, False],
#  ['gearing_up_mind', 'Gearing Up Mind', 1, False],
#  ['ramcosmartbuild', 'Ramco SmartBuild', 1436, False],
#  ['Cryptolab888', 'Cryptolab888', 243, False],
#  ['nrlsalihaa', 'ଘ˚𝒍𝒆𝒚𝒂˚✿', 54, False],
#  ['akemasyraf', 'Kemto', 580, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['DanielABenny', 'Daniel A Benny', 73, False],
#  ['okejuli', 'Eko Julianto', 278, False],
#  ['ridzuaaannn_', '🚀', 470, False],
#  ['apekshasandesh_', 'Apeksha Sandesh', 75, False],
#  ['HydTimes', 'Hyderabad Times', 57199, True],
#  ['So_ongDK', '𝘾𝙞𝙩𝙮 𝙇𝙞𝙜𝙝𝙩𝙨 Nobita', 296, False],
#  ['ieka93', 'HM', 5060, False],
#  ['bwfmedia', 'BWF', 197397, True],
#  ['boysbyw', 'flandus', 3, False],
#  ['bhaswati10', 'Bhaswati Ghosh', 30652, False],
#  ['gonuguntlakish1', 'gonuguntla kishore', 7, False],
#  ['mathisanth', 'Mathisanth Kanagavel', 136, False],
#  ['jigyasu_aadmi', 'jigyasu aadmi', 31, False],
#  ['Cyient', 'Cyient', 19169, False],
#  ['dhavanyakalai', 'Dhavanyakalai', 0, False],
#  ['ranjitkumarTOI', 'Ranjit Kumar', 63, False],
#  ['s_subetha', 'Subetha S', 0, False],
#  ['rajuagn', 'RAJU MANDAL', 87, False],
#  ['Howl_India', 'Howl', 7, False],
#  ['Nameisrajanala', 'APGOTTHEBESTCM', 227, False],
#  ['yeshaa_always', 'Yeshaa Patel ~Fangirl~✨', 288, False],
#  ['DelhiTimesTweet', 'Delhi Times', 77811, True],
#  ['alleygator', 'Rodrigo Hunrichse', 1305, False],
#  ['doulthabad_ps', 'SHO_Doulthabad_PS', 372, False],
#  ['sooraj0222', 'SOORAJ0222', 5, False],
#  ['Chandon_Kala', 'Chandrakala P', 2367, False],
#  ['Jihad76381219', 'Jihad', 0, False],
#  ['are_akash', 'ARE AKASH SAI REDDY🔔', 390, False],
#  ['antony_naveen18', 'Antony Naveen', 45, False],
#  ['KUdhayavani', 'Kalamajiiraranjini Udhayavani', 34, False],
#  ['AmmarAlChalabi', 'Ammar Al-Chalabi', 3462, False],
#  ['nicephoebetiara', 'Blue Gardenia', 219, False],
#  ['ankushparihar32', 'Ankush Parihar', 3, False],
#  ['honey9834', 'Shashank Pandey 🇮🇳🕉️🚩🇮🇳🕉️🚩', 305, False],
#  ['PIBMumbai', 'PIB in Maharashtra 🇮🇳', 58969, True],
#  ['Jayasur41534375', 'Jayasurya', 6, False],
#  ['SuhaniSingh2021', 'Suhani Singh@2021', 1, False],
#  ['VoiceoftheBund', 'Voice of the Bund', 67, False],
#  ['subhanafnankha', 'Subhan Afnan khan', 53, False],
#  ['RomendraRajSin4', 'Romendra Raj Singh', 2, False],
#  ['shrishti_swaraj', 'Shrishti Swaraj', 28, False],
#  ['DanielA39318904', 'Daniel Aguayo', 15, False],
#  ['hkcd_HK', '香港商報', 70, False],
#  ['KasaniVeeresh', 'Veeresh Kasani', 573, False],
#  ['super_gamejin3', '【サッカー好きな】唯のゲーマー', 1, False],
#  ['TODDCastPodcast', 'Todd Hancock', 8420, False],
#  ['venugopalgali', 'Venu Gopal Gali', 5, False],
#  ['vivek_web', 'vivek pandey विवेक', 1311, False],
#  ['Jayanth17656566', 'Nomula Jayanth yadav', 28, False],
#  ['thebulletinbox', 'The Bulletin Box', 22, False],
#  ['ETNOWlive', 'ET NOW', 680918, True],
#  ['NIwJ5vwLxxtzrg7', '五輪生(iwao)', 82, False],
#  ['ct_latha', 'Latha CT', 6, False],
#  ['nitish_0087', 'nitish panwar', 0, False],
#  ['ApexFitzone', 'Apex FitZone', 7, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['sudheeshu', 'Sudheesh U', 130, False],
#  ['jeetbuzz', 'Jeetbuzz', 89, False],
#  ['Sateeshkumar965', 'Sathish Kumar', 3, False],
#  ['bharathkibeti', 'Devashree 🖤', 3145, False],
#  ['bharathkibeti', 'Devashree 🖤', 3145, False],
#  ['BradHast', 'Brad Hast', 479, False],
#  ['kokushokucom', '穀食.com（テレパシー情報屋）', 266, False],
#  ['kaguike', 'K.SoeTa（脱原発に一票）', 714, False],
#  ['morinosekai1414', 'なるみ👒期間限定🎐納涼アイコン(笑)🍧残暑お見舞い申し上げます🍉', 2273, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['gotoutakesi00', 'ごとうたけし', 1304, False],
#  ['FitEkaOc', 'bbyu(L)', 159, False],
#  ['6z_p1', 'ハルの子', 88, False],
#  ['tv9gujarati', 'tv9gujarati', 654482, True],
#  ['ZEE5News', 'ZEE5 News', 34146, True],
#  ['minervaowl_fly', 'Minerva owl', 2152, False],
#  ['8four25jr', '8four25', 146, False],
#  ['mezzobureaucrat', 'Jen J Harewood', 176, False],
#  ['Url4Ever', 'URL4EVER', 23, False],
#  ['narendra_garre', 'Garre Narendra', 176, False],
#  ['narendra_garre', 'Garre Narendra', 176, False],
#  ['FDNYWomen', 'FDNY Women', 2655, False],
#  ['2viciouzC', 'C3ViCiouZ', 16, False],
#  ['SweetCookiesme', 'Arvind', 625, False],
#  ['imAnkeshanand', '#Stay_Home #Stay_Safe 🇮🇳', 217, False],
#  ['Pamela84036781', 'Pamela', 21, False],
#  ['Tanya_Sinclair', 'Tanya Sinclair, CHRE 🇨🇦 🇯🇲', 326, False],
#  ['Corona_SSYT', 'Corona Virus Updates', 2609, False],
#  ['pchopner', 'Paulo Cesar Hopner🇧🇷🏴🐕🔰🌳🌲☘', 3308, False],
#  ['MacalusoJoseph', 'Joseph N Macaluso MD FACS', 1814, False],
#  ['AdamKarbowski', 'Adam Karbowski', 156, False],
#  ['LCoxMPH', 'Lisa Cox PR', 80, False],
#  ['Afterstorm13', 'Afterstorm', 1032, False],
#  ['SportBC', 'Sport BC', 6886, False],
#  ['41OPP', 'Seán Browne', 151, False],
#  ['jamiehansman', 'Jamie Hansman', 228, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['NicolaeCoj373', 'Nicolae Cojocaru', 2, False],
#  ['RobertLanex', 'Robert Lane', 1, False],
#  ['bissettfinfit', 'Tracey Bissett (she/her/hers)', 1300, False],
#  ['Dragofix', 'Dragofix', 4411, False],
#  ['sfischer2010', 'S Fischer', 8658, False],
#  ['sfischer2010', 'S Fischer', 8658, False],
#  ['TodoSports2021', 'Everything Sports', 154, False],
#  ['MimiSayani', 'Shershaah FTW', 1721, False],
#  ['ServerlessFan', 'Serverless Fan', 3693, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['pupijunkul', 'chris⁷ 🍀 | BEcause 🎠', 1268, False],
#  ['PoetOrganic', 'The Organic Poet', 1491, False],
#  ['Nasrull30828303', 'Nasrullah', 1855, False],
#  ['TheSugarMan__', 'ALPHA🧢H.V.M🐺📌', 7024, False],
#  ['Prepsyboard', 'Prepsy', 2, False],
#  ['WESmith91', 'William E. (Bill) Smith', 1025, False],
#  ['robynlisaflynn', 'Robyn Flynn', 5298, False],
#  ['Macaco30301', 'Macaco3030', 29, False],
#  ['CMFSC', 'Coquitlam Metro-Ford SC', 337, False],
#  ['AdeleScorpions', 'Adele Deakes', 581, False],
#  ['ServerlessFan', 'Serverless Fan', 3693, False],
#  ['JackBaure24', 'JackBauer', 253, False],
#  ['pmnorm', 'Dr. Woody/Carpenter Girl', 3224, False],
#  ['ServerlessFan', 'Serverless Fan', 3693, False],
#  ['BonjourKampala', 'Bonjour Kampala', 545, False],
#  ['VandanaThapa3', 'Vandana Thapa', 120, False],
#  ['goodeywrites', 'S. Goodey', 331, False],
#  ['__awitadeuwu__', 'Emilia PM', 25, False],
#  ['Alonso15922455', 'Alonso', 968, False],
#  ['dheeraj_miet', 'Dheeraj Verma', 96, False],
#  ['BaHARsanals', 'BaHARr ///___', 132, False],
#  ['Candelacata1', 'Candelacata1', 64, False]]

# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
schema = StructType([ \
    StructField("Username",StringType(),True), \
    StructField("Name",StringType(),True), \
    StructField("Followers_count", IntegerType(), True), \
    StructField("Verified", StringType(), True) \
  ])
 
df = spark.createDataFrame(data=users_details,schema=schema)
#df.printSchema()
#df.show(truncate=False)
df.where(df.Verified == "true").show()
# Out:
# +---------------+--------------------+---------------+--------+
# |       Username|                Name|Followers_count|Verified|
# +---------------+--------------------+---------------+--------+
# |   RudyCuzzetto|  Rudy Cuzzetto, MPP|           9186|    true|
# |       bwfmedia|                 BWF|         197396|    true|
# |     BPCLimited|    Bharat Petroleum|         315347|    true|
# |       editorji|            editorji|          40753|    true|
# |   Outlookindia|    Outlook Magazine|         233711|    true|
# |       latestly|            LatestLY|          70626|    true|
# |       TheQuint|           The Quint|         683754|    true|
# |   CNBCTV18News|           CNBC-TV18|         957045|    true|
# |    GraziaIndia|        Grazia India|        1587085|    true|
# |    Raghav_Bahl|         Raghav Bahl|         112795|    true|
# |     ndtvvideos|         NDTV Videos|         314308|    true|
# |           ndtv|                NDTV|       16004088|    true|
# | ChicagoCouncil| The Chicago Council|          21519|    true|
# |     BevVincent|         Bev Vincent|           8233|    true|
# |    RusEmbIndia|Russia in India 🇷🇺|          35158|    true|
# |   TBTimes_Rays|         Marc Topkin|          50997|    true|
# | Jerusalem_Post|  The Jerusalem Post|         533689|    true|
# |     muslimgirl|         Muslim Girl|          41582|    true|
# |BrandStoryboard|          Storyboard|          14568|    true|
# |  ShibaniGharat|      Shibani Gharat|          10550|    true|
# +---------------+--------------------+---------------+--------+
# only showing top 20 rows
